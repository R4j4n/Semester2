# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


img = cv2.imread("/home/rjn/Documents/GitHub/Semester2/2203/testimg.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img.shape
# Out:
# (601, 1200)

# %%
df = pd.DataFrame(img)

# %%
# create a secondary image 
height, width = img.shape

# %%
cropped = img[height - height//2 : height  , width - width//2 : width]

# %%
plt.imshow(cropped, cmap='gray')
plt.show()

# %%
t_lower = 50 
t_upper = 200 
aperture_size = 5  
L2Gradient = True  
  
edge = cv2.Canny(img, t_lower, t_upper, L2gradient = L2Gradient )

# %%
plt.imshow(edge, cmap='gray')
plt.show()

# %%
blurred = cv2.GaussianBlur(img, (7, 7), 0)
(T, threshInv) = cv2.threshold(blurred, 50, 100,cv2.THRESH_BINARY_INV)
plt.imshow(threshInv, cmap='gray')
plt.show()

# %%
(T, threshInv) = cv2.threshold(blurred, 0, 255,
	cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
plt.imshow(threshInv, cmap='gray')
plt.show()

# %%
thresh = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10)


plt.imshow(thresh, cmap='gray')
plt.show()

# %%
img = cv2.imread("/home/rjn/Documents/GitHub/Semester2/2203/testimg.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGBA)
img = cv2.resize(img, dsize=(50,50))
plt.imshow(threshInv, cmap='gray')
plt.show()
